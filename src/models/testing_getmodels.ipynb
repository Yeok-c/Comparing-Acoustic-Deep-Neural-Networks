# %%
from get_models import get_model

# %%
Network_architectures = ['VGGISH', 'EfficientNetV1_B0', 'EfficientNetV2_B0',
                         'YAMNET', 'MobileNetV2', 'MobileNetV3']

# %%
# for Archi in Network_architectures:
#     get_model(Archi)
get_model(Network_architectures[5]).summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 96, 64, 1)]  0           []
#
#  Conv (Conv2D)                  (None, 48, 32, 16)   144         ['input_1[0][0]']
#
#  Conv/BatchNorm (BatchNormaliza  (None, 48, 32, 16)  64          ['Conv[0][0]']
#  tion)
#
#  tf.__operators__.add (TFOpLamb  (None, 48, 32, 16)  0           ['Conv/BatchNorm[0][0]']
#  da)
#
#  re_lu (ReLU)                   (None, 48, 32, 16)   0           ['tf.__operators__.add[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 48, 32, 16)   0           ['re_lu[0][0]']
#
#  multiply (Multiply)            (None, 48, 32, 16)   0           ['Conv/BatchNorm[0][0]',
#                                                                   'tf.math.multiply[0][0]']
#
# ...

# %%
# for Archi in Network_architectures:
get_model("YAMNET")
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_1 (InputLayer)        [(None, 96, 64, 1)]       0
#
#  layer1/conv (Conv2D)        (None, 48, 32, 32)        288
#
#  layer1/conv/bn (BatchNormal  (None, 48, 32, 32)       96
#  ization)
#
#  layer1/relu (ReLU)          (None, 48, 32, 32)        0
#
#  layer2/depthwise_conv (Dept  (None, 48, 32, 32)       288
#  hwiseConv2D)
#
#  layer2/depthwise_conv/bn (B  (None, 48, 32, 32)       96
#  atchNormalization)
#
#  layer2/depthwise_conv/relu   (None, 48, 32, 32)       0
#  (ReLU)
#
#  layer2/pointwise_conv (Conv  (None, 48, 32, 64)       2048
#  2D)
#
#  layer2/pointwise_conv/bn (B  (None, 48, 32, 64)       192
#  atchNormalization)
#
#  layer2/pointwise_conv/relu   (None, 48, 32, 64)       0
#  (ReLU)
#
#  layer3/depthwise_conv (Dept  (None, 24, 16, 64)       576
#  hwiseConv2D)
#
# ...
